# %%
import numpy as np 
import pandas as pd 
import sqlite3
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect("EuropeanSoccerDatabase.sqlite") # database name

tables = pd.read_sql("""SELECT *
                        FROM sqlite_master
                        WHERE type='table';""", conn)
tables
# Out:
#     type               name           tbl_name  rootpage  \
# 0  table    sqlite_sequence    sqlite_sequence         4
# 1  table  Player_Attributes  Player_Attributes        11
# 2  table             Player             Player        14
# 3  table              Match              Match        18
# 4  table             League             League        24
# 5  table            Country            Country        26
# 6  table               Team               Team        29
# 7  table    Team_Attributes    Team_Attributes         2
#
#                                                  sql
# 0             CREATE TABLE sqlite_sequence(name,seq)
# 1  CREATE TABLE "Player_Attributes" (\n\t`id`\tIN...
# 2  CREATE TABLE `Player` (\n\t`id`\tINTEGER PRIMA...
# 3  CREATE TABLE `Match` (\n\t`id`\tINTEGER PRIMAR...
# 4  CREATE TABLE `League` (\n\t`id`\tINTEGER PRIMA...
# 5  CREATE TABLE `Country` (\n\t`id`\tINTEGER PRIM...
# 6  CREATE TABLE "Team" (\n\t`id`\tINTEGER PRIMARY...
# ...

# %%
Sqlite_seq = pd.read_sql("""SELECT *
                        FROM sqlite_sequence;""", conn)
Sqlite_seq
# Out:
#                 name     seq
# 0               Team  103916
# 1            Country   51958
# 2             League   51958
# 3              Match   51958
# 4             Player   11075
# 5  Player_Attributes  183978
# 6    Team_Attributes    1458

# %%
Player_attr = pd.read_sql("""SELECT *
                        FROM Player_Attributes;""", conn)
Player_attr
# Out:
#             id  player_fifa_api_id  player_api_id                 date  \
# 0            1              218353         505942  2016-02-18 00:00:00
# 1            2              218353         505942  2015-11-19 00:00:00
# 2            3              218353         505942  2015-09-21 00:00:00
# 3            4              218353         505942  2015-03-20 00:00:00
# 4            5              218353         505942  2007-02-22 00:00:00
# ...        ...                 ...            ...                  ...
# 183973  183974              102359          39902  2009-08-30 00:00:00
# 183974  183975              102359          39902  2009-02-22 00:00:00
# 183975  183976              102359          39902  2008-08-30 00:00:00
# 183976  183977              102359          39902  2007-08-30 00:00:00
# 183977  183978              102359          39902  2007-02-22 00:00:00
#
#         overall_rating  potential preferred_foot attacking_work_rate  \
# ...

# %%
Player_attr[Player_attr['player_api_id']==505942]
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
Player_attr.columns
# Out:
# Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
Players = pd.read_sql("""SELECT *
                        FROM Player;""", conn)
Players
# Out:
#           id  player_api_id          player_name  player_fifa_api_id  \
# 0          1         505942   Aaron Appindangoye              218353
# 1          2         155782      Aaron Cresswell              189615
# 2          3         162549          Aaron Doran              186170
# 3          4          30572        Aaron Galindo              140161
# 4          5          23780         Aaron Hughes               17725
# ...      ...            ...                  ...                 ...
# 11055  11071          26357       Zoumana Camara                2488
# 11056  11072         111182         Zsolt Laczko              164680
# 11057  11073          36491            Zsolt Low              111191
# 11058  11074          35506  Zurab Khizanishvili               47058
# 11059  11075          39902   Zvjezdan Misimovic              102359
#
#                   birthday  height  weight
# 0      1992-02-29 00:00:00  182.88     187
# 1      1989-12-15 00:00:00  170.18     146
# ...

# %%
Matches = pd.read_sql("""SELECT *
                        FROM Match;""", conn)
Matches
# Out:
#           id  country_id  league_id     season  stage                 date  \
# 0          1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1          2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2          3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3          4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4          5           1          1  2008/2009      1  2008-08-16 00:00:00
# ...      ...         ...        ...        ...    ...                  ...
# 25974  25975       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25975  25976       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25976  25977       24558      24558  2015/2016      9  2015-09-23 00:00:00
# 25977  25978       24558      24558  2015/2016      9  2015-09-22 00:00:00
# 25978  25979       24558      24558  2015/2016      9  2015-09-23 00:00:00
#
# ...

# %%
Matches['country_id'].unique()
# Out:
# array([    1,  1729,  4769,  7809, 10257, 13274, 15722, 17642, 19694,
#        21518, 24558], dtype=int64)

# %%
Matches.columns
# Out:
# Index(['id', 'country_id', 'league_id', 'season', 'stage', 'date',
#        'match_api_id', 'home_team_api_id', 'away_team_api_id',
#        'home_team_goal',
#        ...
#        'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH', 'BSD', 'BSA'],
#       dtype='object', length=115)

# %%
pd.set_option('display.max_columns', None)
Matches.head()
# Out:
#    id  country_id  league_id     season  stage                 date  \
# 0   1           1          1  2008/2009      1  2008-08-17 00:00:00
# 1   2           1          1  2008/2009      1  2008-08-16 00:00:00
# 2   3           1          1  2008/2009      1  2008-08-16 00:00:00
# 3   4           1          1  2008/2009      1  2008-08-17 00:00:00
# 4   5           1          1  2008/2009      1  2008-08-16 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        492473              9987              9993               1
# 1        492474             10000              9994               0
# 2        492475              9984              8635               0
# 3        492476              9991              9998               5
# 4        492477              7947              9985               1
#
#    away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# 0               1             NaN             NaN             NaN
# ...

# %%
Leagues = pd.read_sql("""SELECT *
                        FROM League;""", conn)
Leagues
# Out:
#        id  country_id                      name
# 0       1           1    Belgium Jupiler League
# 1    1729        1729    England Premier League
# 2    4769        4769            France Ligue 1
# 3    7809        7809     Germany 1. Bundesliga
# 4   10257       10257             Italy Serie A
# 5   13274       13274    Netherlands Eredivisie
# 6   15722       15722        Poland Ekstraklasa
# 7   17642       17642  Portugal Liga ZON Sagres
# 8   19694       19694   Scotland Premier League
# 9   21518       21518           Spain LIGA BBVA
# 10  24558       24558  Switzerland Super League

# %%
Countries = pd.read_sql("""SELECT *
                        FROM Country;""", conn)
Countries
# Out:
#        id         name
# 0       1      Belgium
# 1    1729      England
# 2    4769       France
# 3    7809      Germany
# 4   10257        Italy
# 5   13274  Netherlands
# 6   15722       Poland
# 7   17642     Portugal
# 8   19694     Scotland
# 9   21518        Spain
# 10  24558  Switzerland

# %%
Teams = pd.read_sql("""SELECT *
                        FROM Team;""", conn)
Teams
# Out:
#         id  team_api_id  team_fifa_api_id      team_long_name team_short_name
# 0        1         9987             673.0            KRC Genk             GEN
# 1        2         9993             675.0        Beerschot AC             BAC
# 2        3        10000           15005.0    SV Zulte-Waregem             ZUL
# 3        4         9994            2007.0    Sporting Lokeren             LOK
# 4        5         9984            1750.0   KSV Cercle Brugge             CEB
# ..     ...          ...               ...                 ...             ...
# 294  49479        10190             898.0       FC St. Gallen             GAL
# 295  49837        10191            1715.0             FC Thun             THU
# 296  50201         9777             324.0         Servette FC             SER
# 297  50204         7730            1862.0  FC Lausanne-Sports             LAU
# 298  51606         7896               NaN              Lugano             LUG
#
# [299 rows x 5 columns]

# %%
Team_attr = pd.read_sql("""SELECT *
                        FROM Team_Attributes;""", conn)
Team_attr
# Out:
#         id  team_fifa_api_id  team_api_id                 date  \
# 0        1               434         9930  2010-02-22 00:00:00
# 1        2               434         9930  2014-09-19 00:00:00
# 2        3               434         9930  2015-09-10 00:00:00
# 3        4                77         8485  2010-02-22 00:00:00
# 4        5                77         8485  2011-02-22 00:00:00
# ...    ...               ...          ...                  ...
# 1453  1454             15005        10000  2011-02-22 00:00:00
# 1454  1455             15005        10000  2012-02-22 00:00:00
# 1455  1456             15005        10000  2013-09-20 00:00:00
# 1456  1457             15005        10000  2014-09-19 00:00:00
# 1457  1458             15005        10000  2015-09-10 00:00:00
#
#       buildUpPlaySpeed buildUpPlaySpeedClass  buildUpPlayDribbling  \
# 0                   60              Balanced                   NaN
# 1                   52              Balanced                  48.0
# ...

# %% [markdown]
# ### Analysis using SQL operations

# %% [markdown]
# #### 1. Joining countries and leagues tables!!

# %%
country_league = pd.read_sql("""SELECT * FROM Country
JOIN League
ON Country.id=League.id""", conn)
country_league
# Out:
#        id         name     id  country_id                      name
# 0       1      Belgium      1           1    Belgium Jupiler League
# 1    1729      England   1729        1729    England Premier League
# 2    4769       France   4769        4769            France Ligue 1
# 3    7809      Germany   7809        7809     Germany 1. Bundesliga
# 4   10257        Italy  10257       10257             Italy Serie A
# 5   13274  Netherlands  13274       13274    Netherlands Eredivisie
# 6   15722       Poland  15722       15722        Poland Ekstraklasa
# 7   17642     Portugal  17642       17642  Portugal Liga ZON Sagres
# 8   19694     Scotland  19694       19694   Scotland Premier League
# 9   21518        Spain  21518       21518           Spain LIGA BBVA
# 10  24558  Switzerland  24558       24558  Switzerland Super League

# %% [markdown]
# #### 2. Joining country, league, and match tables!!

# %%
detailed_matches = pd.read_sql("""SELECT Match.id, 
                                        Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season, 
                                        stage AS matchweek, 
                                        date,
                                        HT.team_long_name AS  home_team,
                                        AT.team_long_name AS away_team,
                                        home_team_goal, 
                                        away_team_goal                                        
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                ORDER by date
                                LIMIT 10""", conn)
detailed_matches
# Out:
#       id country_name               league_name     season  matchweek  \
# 0  24559  Switzerland  Switzerland Super League  2008/2009          1
# 1  24560  Switzerland  Switzerland Super League  2008/2009          1
# 2  24561  Switzerland  Switzerland Super League  2008/2009          1
# 3  24562  Switzerland  Switzerland Super League  2008/2009          1
# 4  24613  Switzerland  Switzerland Super League  2008/2009          2
# 5  24614  Switzerland  Switzerland Super League  2008/2009          2
# 6  24615  Switzerland  Switzerland Super League  2008/2009          2
# 7  24616  Switzerland  Switzerland Super League  2008/2009          2
# 8  24617  Switzerland  Switzerland Super League  2008/2009          2
# 9  24668  Switzerland  Switzerland Super League  2008/2009          3
#
#                   date        home_team                away_team  \
# 0  2008-07-18 00:00:00   BSC Young Boys                 FC Basel
# ...

# %% [markdown]
# #### 3. Joining player and player attributes!!

# %%
player_details=pd.read_sql("""SELECT Player.player_api_id, player_name,  date, height, weight, overall_rating, potential, preferred_foot, attacking_work_rate, defensive_work_rate
FROM Player
JOIN Player_Attributes
ON Player.player_api_id=Player_Attributes.player_api_id
WHERE overall_rating>70
GROUP BY player_name
LIMIT 10
""", conn)

player_details
# Out:
#    player_api_id      player_name                 date  height  weight  \
# 0         155782  Aaron Cresswell  2016-04-21 00:00:00  170.18     146
# 1         162549      Aaron Doran  2013-09-20 00:00:00  170.18     163
# 2          30572    Aaron Galindo  2009-08-30 00:00:00  182.88     198
# 3          23780     Aaron Hughes  2014-09-18 00:00:00  182.88     154
# 4          27316       Aaron Hunt  2016-04-28 00:00:00  182.88     161
# 5          30895     Aaron Lennon  2015-10-16 00:00:00  165.10     139
# 6          23889    Aaron Mokoena  2010-08-30 00:00:00  182.88     181
# 7         231592       Aaron Mooy  2016-02-04 00:00:00  175.26     150
# 8          40719     Aaron Niguez  2015-12-17 00:00:00  170.18     143
# 9          75489     Aaron Ramsey  2016-03-10 00:00:00  177.80     154
#
#    overall_rating  potential preferred_foot attacking_work_rate  \
# 0              74         76           left                high
# ...

# %% [markdown]
# #### 4. Basic arithmetic operations of league statistics

# %%
leages_by_season = pd.read_sql("""SELECT Country.name AS country_name, 
                                        League.name AS league_name, 
                                        season,
                                        count(distinct stage) AS number_of_matchweeks,
                                        count(distinct HT.team_long_name) AS number_of_teams,
                                        avg(home_team_goal) AS avg_home_team_goal, 
                                        avg(away_team_goal) AS avg_away_team_goals, 
                                        avg(home_team_goal-away_team_goal) AS avg_goal_dif, 
                                        avg(home_team_goal+away_team_goal) AS avg_goals, 
                                        sum(home_team_goal+away_team_goal) AS total_goals                                       
                                FROM Match
                                JOIN Country on Country.id = Match.country_id
                                JOIN League on League.id = Match.league_id
                                LEFT JOIN Team AS HT on HT.team_api_id = Match.home_team_api_id
                                LEFT JOIN Team AS AT on AT.team_api_id = Match.away_team_api_id
                                GROUP BY Country.name, League.name, season
                                HAVING count(distinct stage) > 10
                                ORDER BY Country.name, season DESC
                                LIMIT 10""", conn)
leages_by_season
# Out:
#   country_name             league_name     season  number_of_matchweeks  \
# 0      Belgium  Belgium Jupiler League  2015/2016                    30
# 1      Belgium  Belgium Jupiler League  2014/2015                    30
# 2      Belgium  Belgium Jupiler League  2012/2013                    30
# 3      Belgium  Belgium Jupiler League  2011/2012                    30
# 4      Belgium  Belgium Jupiler League  2010/2011                    30
# 5      Belgium  Belgium Jupiler League  2009/2010                    30
# 6      Belgium  Belgium Jupiler League  2008/2009                    34
# 7      England  England Premier League  2015/2016                    38
# 8      England  England Premier League  2014/2015                    38
# 9      England  England Premier League  2013/2014                    38
#
#    number_of_teams  avg_home_team_goal  avg_away_team_goals  avg_goal_dif  \
# 0               16            1.675000             1.216667      0.458333
# ...

# %% [markdown]
# ## Query Run Order
# ### Now that we are familiar with most of the functionalities being used in a query, it is very important to understand the order that code runs.
#
# ### As we mentioned, here is the order as it would appear in the code:
#
# ### SELECT
# ### FROM
# ### JOIN
# ### WHERE
# ### GROUP BY
# ### HAVING
# ### ORDER BY
# ### LIMIT
# ### You can think of it as a two part process: First, create a new temporal table in the memory:
#
# #### 1 .Define which tables to use, and connect them (FROM + JOIN)
# #### 2. Keep only the rows that apply to the conditions (WHERE)
# #### 3. Group the data by the required level (if need) (GROUP BY)
# #### 4. Choose what information you want to have in the new table. It can have just rawdata (if no grouping), or combination of dimensions (from the grouping), and metrics Then, choose what to show from the table:
# #### 5 .Order the output of the new table (ORDER BY)
# #### 6. Add more conditions that would filter the new created table (HAVING)
# #### 7. Limit to number of rows - would cut it according the soring and the having filtering (LIMIT)
